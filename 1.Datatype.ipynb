# %%
a=100
print(type(a))

b=3.45
print(type(b))

c="Hello"
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#Identify the data type of False.

s=False
print(type(s))
# Out:
# <class 'bool'>

# %%
#What is the output of type(25)?
x=5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ###Integer and Float Questions

# %%
a=20
b=12.5
print(type(a))
print(type(b))

#Add an integer and a float.
print(a+b)
# Out:
# <class 'int'>
# <class 'float'>
# 32.5

# %%
#Multiply two float values.
a=45.5
b=56.6
print(a+b)
# Out:
# 102.1

# %%
#Convert an integer to a float.
a=5
b=float(a)
print(b)
# Out:
# 5.0

# %%
#Convert a float to an integer.
b=88.8
c=int(b)
print(c)
# Out:
# 88

# %%
a=5
b=5.5
c=a+b
print(type(c))
# Out:
# <class 'float'>

# %% [markdown]
# ###String Questions

# %%
a='anu'
print(type(a))
print(len(a))
print(a.upper())
print(a.lower())
print(a[0])
print(a[-1])
# Out:
# <class 'str'>
# 3
# ANU
# anu
# a
# u

# %%
#Concatenate two strings.
a='as'
b='zx'
print(a,b) #, will give space + will not
# Out:
# as zx

# %%
#Repeat a string 3 times.
a='dell'
print(a * 3)
# Out:
# delldelldell

# %%
a=True
b=False
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
10>5
# Out:
# True

# %%
type(10>5)
# Out:
# bool

# %% [markdown]
# ### conversion

# %%
a='100'
print(type (a))
b=int(a)

print(b)
print(type(b))
# Out:
# <class 'str'>
# 100
# <class 'int'>

# %%
a=50
print(type(a))

b=str(a)
print(b)
print(type(b))
# Out:
# <class 'int'>
# 50
# <class 'str'>

# %%
#Convert 0 into a boolean

a=0
print(type(a))

b=bool(a)
print(b)
print(type(b))
# Out:
# <class 'int'>
# False
# <class 'bool'>

# %%
a=1
print(type(a))

b=bool(a)
print(b)
print(type(b))
# Out:
# <class 'int'>
# True
# <class 'bool'>
