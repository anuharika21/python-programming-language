# %%
try:
  a = 10
  b = 20
  print(a / b)


except Exception as e:
  print(e)
# Out:
# 0.5

# %%
a = 10
b = 0

print(a / b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1338/1844804004.py in <cell line: 0>()
#       2 b = 0
#       3
# ----> 4 print(a / b)
#
# ZeroDivisionError: division by zero

# %%
try:
  a=10
  b=0
  print(a/b)

except Exception as e:
  print(e)
# Out:
# division by zero

# %%
import sys

try:
  a = 10
  b = 0
  print(a / b)


except Exception as e:
  print(f"Error msg from try block : {e}")
  er_ty , er_msg , er_line = sys.exc_info()
  print(f"Error type : {er_ty}")
  print(f"Error Msg : {er_msg}")
  print(f"Error Line no : {er_line.tb_lineno}")
# Out:
# Error msg from try block : division by zero
# Error type : <class 'ZeroDivisionError'>
# Error Msg : division by zero
# Error Line no : 6

# %%
import sys


try:
  a = 10
  b = 0
  print(a / b)


except Exception as e:
  er_ty , er_msg , er_line = sys.exc_info()
  print(f"Error in Line no : {er_line.tb_lineno} : Due to : {er_ty} : Reason : {er_msg}")
# Out:
# Error in Line no : 7 : Due to : <class 'ZeroDivisionError'> : Reason : division by zero

# %%
try:
  def sharuk(n):
    s = 0
    for i in range(1,n):
      if n % 0 == 0:
        s = s + i

    if s == n:
      print(f"Perfect Number : {n}")
    else:
      print(f"Not a Perfect NUmber : {n}")


  sharuk(6)

except Exception as e:
  er_ty , er_msg , er_line = sys.exc_info()
  print(f"Error in Line no : {er_line.tb_lineno} : Due to : {er_ty} : Reason : {er_msg}"

# %% [markdown]
# 2. ValueError

# %%
a = 'k'
b = int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1338/3642938554.py in <cell line: 0>()
#       1 a = 'k'
# ----> 2 b = int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'k'

# %% [markdown]
# 3. NameError

# %%
a = 'kamal'
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1338/4194803985.py in <cell line: 0>()
#       1 a = 'kamal'
# ----> 2 print(l)
#
# NameError: name 'l' is not defined

# %% [markdown]
# 4. IOError

# %%
# File Handling concept
with open('kamal.txt','w') as f:
    f.write('Python Programming Language File Handling concept and IOError ')
    f.close()

# %%
# Read The File
with open('kamal.txt','r') as f:
    print(f.read())
    f.close()
# Out:
# Python Programming Language File Handling concept and IOError

# %%
with open('python.txt','r') as f:
    print(f.read())
    f.close()

# %% [markdown]
# 5. Indentation Error

# %%
a = [1,2,3,4]
for i in a:
    print(i,end=" ")
# Out:
# 1 2 3 4

# %%
a = [1,2,3,4]
for i in a:
print(i)
# Out:
#   File "/tmp/ipykernel_1338/1107055401.py", line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
try:
  a=int(input("enter a number="))
  b=a/0
  print(b)

except:
  print("dont give 0 in denominator")
# Out:
# enter a number=4
# dont give 0 in denominator

# %%
try:
    a = int(input("Enter a Number = "))
    b = a / 0
    rint(b)
except Exception as f:
    print(f)
# Out:
# Enter a Number = 4
# division by zero

# %%
num1 = input("Please enter a number")
try:
    num2 = int(num1)
    print(num2)
except Exception as f:
    print(f)
    print("Please enter the correct input")
print("Outside of try-except clauses. This statement is always executed.")
# Out:
# Please enter a numbert
# invalid literal for int() with base 10: 't'
# Please enter the correct input
# Outside of try-except clauses. This statement is always executed.

# %%
num1 = input("Please enter a number : ")
try:
    num2 = int(num1)
    num3 = 10/num2
    print(num3)

except ValueError:
    print("Please enter a numeric value")

except ZeroDivisionError:
    print("Please enter a non-zero value")
# Out:
# Please enter a number : p
# Please enter a numeric value

# %%
#Python Raising an Exception
try:
    roll = int(input("Please enter your roll number"))
    if roll <= 0:
        raise ValueError()

except ValueError:
    print("Pls Give positive Value only ")

print("Outside of try-except clauses.")
# Out:
# Please enter your roll number-9
# Pls Give positive Value only
# Outside of try-except clauses.

# %%
try:
    roll = int(input("Please enter your roll number"))
    if roll <= 0:
        raise ValueError("The number entered is not positive")

except ValueError as v:
    print("ValueError Exception thrown")
    print(v)

print("Outside of try-except clauses.")
# Out:
# Please enter your roll number-4
# ValueError Exception thrown
# The number entered is not positive
# Outside of try-except clauses.

# %%
try:
    #this will throw an exception if the file doesn't exist.
    a = open("kamal.txt","r")
    print(a.read())
except IOError as f:
    print("File not found")
    print(f)
else:
    print("The file opened successfully")
    fileptr.close()
# Out:
# Python Programming Language File Handling concept and IOError
# The file opened successfully
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1338/2323956791.py in <cell line: 0>()
#       8 else:
#       9     print("The file opened successfully")
# ---> 10     fileptr.close()
#
# NameError: name 'fileptr' is not defined
