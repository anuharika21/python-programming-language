# %%
class CSE:
  f=100
  g=200

  def cse(self):
    print(self.f + self.g)

anil=CSE()
anil.cse()
# Out:
# 300

# %%
class CSE:
  f=100
  g=200

  def manu(self):
    t=20
    s=39
    print(self.f + self.g + t+s)

  def sharuk(self):

    p=23
    a=34

cse=CSE()
cse.manu()
# Out:
# 359

# %%
class CSE:
  f=40

  def __init__(self,n):
    print("good morning",n)

anil=CSE(5)
# Out:
# good morning 5

# %%
class AS:
  e=100

  def __init__(self,x,y):
    self.x=x
    self.y=y

anil=AS(2,3)
print(anil.x + anil.e + anil.y)
# Out:
# 105

# %%
# without constructor

class CALCULATIONS:
  f = 2
  p = 3

  def addition(self):
    print(self.f + self.p)

  def subtraction(self):
    print(self.f - self.p)


anil = CALCULATIONS()
anil.addition()
anil.subtraction()

# %%
class CALCULATIONS:
  def __init__(self,g,h):
    self.g=g
    self.h=h

  def addition(self):
    self.r=self.g + self.h

  def subtraction(self):
    self.r1=self.g - self.h

  def common(self):
    print(self.r + self.r1)

cal=CALCULATIONS(1,2)
cal.addition()
cal.subtraction()
cal.common()
# Out:
# 2

# %% [markdown]
# calculater

# %%
class CALCULATOR:
  def __init__(self,v1,v2):
    self.v1=v1
    self.v2=v2

  def addition(self):
    print(self.v1 + self.v2)

  def subtraction(self):
    print(self.v1 - self.v2)

  def multipit(self):
    print(self.v1 * self.v2)


  def division(self):
    print(self.v1 / self.v2)


v1=int(input("enter a value"))
v2=int(input("enter a value"))
operator=input("enter a operator")

cal=CALCULATOR(v1,v2)
if operator == '+':
  cal.addition()

elif operator == '-':
  cal.subtraction()

elif operator =='*':
  cal.multiply()

else:
  cal.division()
# Out:
# enter a value1
# enter a value2
# enter a operator+
# 4

# %%
class EMP:
  def __init__(self,id,name):
    self.id=id
    self.name=name

  def details(self):
    print(f"ID:{self.id}\nNAME:{self.name}")

emp1=EMP(102,'shinchan')
emp2=EMP(103,"himavari")
emp1.details()
emp2.details()
# Out:
# ID:102
# NAME:shinchan
# ID:103
# NAME:himavari

# %% [markdown]
# counting obj

# %%
class student:
  count=0
  def __init__(self):
    student.count=student.count+1

s1=student()
s2=student()
s3=student()

print("the no.of student:",student.count)
# Out:
# the no.of student: 3

# %%
class Student:
    # Constructor - non parameterized
    def __init__(self):
        print("This is non parametrized constructor")
    def show(self,name):
        print("Hello",name)
student = Student()
student.show("John")
# Out:
# This is non parametrized constructor
# Hello John

# %%
class Student:
    # Constructor - parameterized
    def __init__(self, name):
        print("This is parametrized constructor")
        self.name = name
    def show(self):
        print("Hello",self.name)
obj = Student("John")
obj.show()
# Out:
# This is parametrized constructor
# Hello John

# %%
class Student:
    def __init__(self):
        print("The First Constructor")
    def __init__(self):
        print("The second time contructor")

st = Student()
a = Student()
# Out:
# The second time contructor
# The second time contructor

# %% [markdown]
# Design a BankAccount class with a constructor that initializes the account holder’s name and balance.

# %%
class BANKACC:
  def __init__(self,name,balance):
    self.name=name
    self.balance=balance

  def deposit(self,amount):
    self.balance+=amount

  def display(self):
    print("account holder",self.name)
    print('balancee',self.balance)

acc=BANKACC("anu",9000)
acc.deposit(10000)
acc.display()
# Out:
# account holder anu
# balancee 19000

# %% [markdown]
# # area of rectangle

# %%
class RECTANGLE:
  def __init__(self,lenght,width):
    self.length=lenght
    self.width=width

  def area(self):
    return self.length*self.width

r=RECTANGLE(10,5)
print('area',r.area())
# Out:
# area 50

# %%
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display(self):
        print("Title :", self.title)
        print("Author:", self.author)
        print("Price :", self.price)


b = Book("Python Programming", "John Doe", 499)
b.display()
# Out:
# Title : Python Programming
# Author: John Doe
# Price : 499

# %%
class Car:
    def __init__(self, brand="Toyota", model="Corolla"):
        self.brand = brand
        self.model = model

    def display(self):
        print("Brand:", self.brand)
        print("Model:", self.model)

c1 = Car()                  # Uses default values
c2 = Car("Honda", "City")   # Custom values

c1.display()
c2.display()
# Out:
# Brand: Toyota
# Model: Corolla
# Brand: Honda
# Model: City

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


c = Circle(7)
print("Area =", c.area())
# Out:
# Area = 153.93804002589985

# %%
class Employee:
    next_id = 1  # class variable

    def __init__(self, name):
        self.name = name
        self.emp_id = Employee.next_id
        Employee.next_id += 1

    def display(self):
        print("ID:", self.emp_id)
        print("Name:", self.name)


e1 = Employee("Anu")
e2 = Employee("Rahul")

e1.display()
e2.display()
# Out:
# ID: 1
# Name: Anu
# ID: 2
# Name: Rahul
