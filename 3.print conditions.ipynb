# %% [markdown]
# #Strings can be assigned to variable say string1 and string2 which can called when using the print statement.

# %%
string1='word'
print('hello',string1)

string2="!"
print('hello',string1,string2)
# Out:
# hello word
# hello word !

# %% [markdown]
# ## rules

# %%
a = 'Data science'
b = 'Machine learning'
print("Python can do both "+a+" and "+b)
print("Python and "+a)
# Out:
# Python can do both Data science and Machine learning
# Python and Data science

# %%
s1='sunday'
s2="12:30 am"

print("today is" ,s1 , "time is " ,s1)
# Out:
# today is sunday time is  sunday

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# **rule 2**
#
# add string with string

# %%
f=29
print("my name is anu "+str(f))
# Out:
# my name is anu 29

# %% [markdown]
# ## rule 3
# %d,%f,%s

# %%
c="anu"
print("my name is %s"%c)
# Out:
# my name is anu

# %%
a=2
b=3.3
c="anu"

print("integer %d and float %f and sting %s"%(a,b,c))
# Out:
# integer 2 and float 3.300000 and sting anu

# %% [markdown]
# ## rule 4
# f {}

# %%
a=23
b=45
print(f"my age is {a} and height is {b}")
# Out:
# my age is 23 and height is 45

# %% [markdown]
# ##2: Multiple print Statements

# %%
print("anu")
print(24)
# Out:
# anu
# 24

# %%
#Print days of the week using multiple print statement
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")

# %%
print("Favorite Movie: Inception", end=" | ")
print("Favorite Actor: Leonardo DiCaprio")

#on same line

# %% [markdown]
# ## Escape Sequences

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
print("hello\tworld\tANu")
# Out:
# hello	world	ANu

# %%
print("name:\tanu\nAge:\t22")
# Out:
# name:	anu
# Age:	22

# %%
print("python\n\tData analytics")
# Out:
# python
# 	Data analytics

# %%
print("a\nb\nc")
# Out:
# a
# b
# c

# %%
print('''the
cloud''')
# Out:
# the cloud

# %%
print(r'users\anu')
print("D:\\Projects\\Python\\main.py")
# Out:
# users\anu
# D:\Projects\Python\main.py

# %%
print("\"")
# Out:
# "

# %%
print("\\")
# Out:
# \

# %% [markdown]
# ## Patterns Using Print

# %%
print("*")
# Out:
# *

# %%
print('''#
##
###
####''')
# Out:
# #
# ##
# ###
# ####

# %% [markdown]
# ## Print with Variables

# %%
name="anu"
age=22
print("name:",name, "\nage",age)
# Out:
# name: anu
# age 22

# %%
name="alekhya"
age='22'
city='hyd'
print("student\n-----------------------------")
print("name:\t",name ,"\nage:\t",age ,"\ncity:\t",city)
# Out:
# student
# -----------------------------
# name:	 alekhya
# age:	 22
# city:	 hyd

# %% [markdown]
# **print stmts rules**
# ** -'R1'**

# %%
course="artificila"
time=12.30
duration=7

print("iam learning" ,course ,"course time" ,time, "and duration",duration)
# Out:
# iam learning artificila course time 12.3 and duration 7

# %% [markdown]
# **R2**
# **+ with 1 tab space**

# %%
course="artificila"
time=12.30
duration=7
print("im learning " +course+"in viharatech time " +str(time)+" duration"+str(duration))
# Out:
# im learning artificilain viharatech time 12.3 duration7

# %% [markdown]
# # **R3** identifiers
#
#
# *   %d int
# *   %s  str
# *   %f float

# %%
course="artificila"
time=12.30
duration=7

print("im learing %s in viharatech time %f and duration %d"%(course,time,duration))
# Out:
# im learing artificila in viharatech time 12.300000 and duration 7

# %% [markdown]
# # **R4**
# f"{}'

# %%
course="artificila"
time=12.30
duration=7

print(f"im learing {course} in vihara tech time {time} duration {duration}")
# Out:
# im learing artificila in vihara tech time 12.3 duration 7
